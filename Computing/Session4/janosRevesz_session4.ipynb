# %% [markdown]
# ## <a id="task"></a>Plotting data from x-ray scattering experiment

# %% [markdown]
# This jupyter notebook is about plotting the data from an x-ray diffraction experiment performed with LiF and NaCl.

# %% [markdown]
# ### <a id="task"></a>Python code

# %% [markdown]
# The code below imports the libraries used in the code and makes the plot interactable to the reader.

# %%
# %matplotlib notebook
import numpy as np

# %% [markdown]
# Loading the data from two csv files to 4 arrays using the numpy library. There are 86 data points for NaF and 76 for NaCl

# %%
# load data from csv1
LiFdataX, LiFdataY = np.loadtxt("LiF-30kV.csv", delimiter=',', skiprows=1, unpack=True)
# load data from csv2
NaCldataX, NaCldataY = np.loadtxt("NaCl-30kV.csv", delimiter=',', skiprows=1, unpack=True)

# %% [markdown]
# Creating the plot using the matplotlib library and saving it to a pdf file for future usage. The Y axes shows the number of counts per second while the X axes shows the diffraction angle times two.

# %%
c
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Because of the spikes along the Y axes the data is not continous, therefore fitting a continous line along the points without the points themselves would be missleading. The line added along the blue points is to make the graph more readable.
